# %% [markdown]
# ## Cloning Repo to Colab

# %%
# !ssh-keygen -t ed25519 -C "your_email@example.com" -N "" -f /root/.ssh/id_ed25519

# %%
# !cat /root/.ssh/id_ed25519.pub

# %% [markdown]
# Add Key to GitHub
#
# Go to GitHub SSH Settings.
# Click New SSH key.
#
# Give it a title (e.g., "Google Colab") and paste your copied key into the Key field.
#
# Click Add SSH key.

# %%
# Test connection
# !ssh -T git@github.com
# Out:
# Cloning into 'my-projects'...
# remote: Enumerating objects: 18, done.
# remote: Counting objects: 100% (18/18), done.
# remote: Compressing objects: 100% (15/15), done.
# remote: Total 18 (delta 2), reused 12 (delta 1), pack-reused 0 (from 0)
# Receiving objects: 100% (18/18), 1023.74 KiB | 7.26 MiB/s, done.
# Resolving deltas: 100% (2/2), done.

# %%
# Clone your repo (use the SSH URL, not HTTPS)
# !git clone git@github.com:username/repository.git
