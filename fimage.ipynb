# %%
pip install fimage
# Out:
# Collecting fimage
#   Downloading fimage-0.2.3-py3-none-any.whl (9.2 kB)
# Collecting Pillow<9.0.0,>=8.0.0 (from fimage)
#   Downloading Pillow-8.4.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 14.5 MB/s eta 0:00:00
# Requirement already satisfied: numpy<2.0.0,>=1.21.4 in /usr/local/lib/python3.10/dist-packages (from fimage) (1.25.2)
# Installing collected packages: Pillow, fimage
#   Attempting uninstall: Pillow
#     Found existing installation: Pillow 9.4.0
#     Uninstalling Pillow-9.4.0:
#       Successfully uninstalled Pillow-9.4.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# fastai 2.7.15 requires pillow>=9.0.0, but you have pillow 8.4.0 which is incompatible.
# Successfully installed Pillow-8.4.0 fimage-0.2.3

# %%
from fimage import FImage
from fimage.filters import Sepia


def main():
    # replace 'my_picture.jpg' with the path to your image
    image = FImage('/content/drive/MyDrive/Colab Notebooks/Image_DB/IMG_1895.jpg')

    # apply the Sepia filter to the image
    image.apply(Sepia(90))

    # save the image with the applied filter
    image.save('/content/drive/MyDrive/Colab Notebooks/Image_DB/IMG_1895_sepia.jpg')


if __name__ == "__main__":
    main()
